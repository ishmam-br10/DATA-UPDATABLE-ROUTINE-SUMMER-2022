# %%
file = open('routine.txt', mode='r')
routine = file.readlines()  # make the file a list

stid = input("Enter your BRAC UNIVERSITY ID : ")
for i in range(len(routine)):
    if (stid + '\n') in routine:
        file = open('routine.txt', mode='r')
        routine = file.readlines()
        num1 = len(routine)  # length of the full list
        code_id = 0  # index of his/her id at in the list
        
        # take id as an input

        # make a loop to find the user
        for i in range(0, num1):
            if routine[i] == (stid + '\n'):
                code_id = i
        # print welcome message
        print("---------------------------------------")
        print("WELCOME! ", routine[code_id + 1])

        # take input of day and time from user
        day = input("ENTER FIRST THREE LETTER OF THE DAY (EG. SAT, SUN) : ")
        time = input("ENTER TIME IN INTERNATIONAL FORMAT: ")
        day_list = ['SAT', 'SUN', 'MON', 'TUE', 'WED', 'THU', 'FRI']
        start_day = 0
        end_day = 0
        start_time = 0
        day_num1 = 0
        day_num2 = 0

        for i in range(0, len(day_list)):
            if (day == day_list[i]):
                day_num1 = i
                day_num2 = i + 1

        for i in range(code_id, num1):
            if ((day_list[day_num1] + '\n') == routine[i]):
                start_day = i
                break
        for i in range(code_id, num1):
            if ((day_list[day_num2] + '\n') == routine[i]):
                end_day = i
                break

        # OUTPUT
        flag = True
        for i in range(start_day, end_day):
            if ((time + '\n') == routine[i]):
                start_time = i
                print("NAME: ", routine[code_id + 1], end="")
                print("COURSE CODE : ", routine[start_time + 1], end="")
                print("FACULTY : ", routine[start_time + 2], end="")
                print("ROOM NUMBER : ", routine[start_time + 3], end="")
                print("DURATION : ", routine[start_time + 4], end="")
                break
        else:
            flag = False
        if flag == False:
            print("No class starts now !")

        break

else:
    print("YOU DON'T HAVE YOUR DATA ON OUR DATABSE")

    file = open('routine.txt', mode='a')
    print('UPDATE YOUR INFORMATION: ')
    STUDENT_ID = input("Enter your student id : ")
    NAME = input("ENTER YOUR NAME : ")
    file.write(STUDENT_ID + '\n')
    file.write(NAME + '\n')
    print('UPDATE YOUR INFORMATION FOR SATURDAY : ')
    file.write('SAT\n')
    count_sat = int(input("SATURDAY TOTAL CLASS: "))
    for i in range(0, count_sat):
        time = input("ENTER THE CLASS TIME IN INTERNATIONAL FORMAT : ")
        file.write(time + '\n')
        course_code = input("ENTER THE COURSE CODE : ")
        file.write(course_code + '\n')
        faculty = input("ENTER THE FACULTY SHORT FORM:  ")
        file.write(faculty + '\n')
        room_number = input("ENTER THE ROOM NUMBER : ")
        file.write(room_number + '\n')
        duration = input("ENTER THE CLASS DURATION: ")
        file.write(duration + '\n')
    ########## SUNDAY

    print('UPDATE YOUR INFORMATION FOR SUNDAY : ')
    file.write('SUN\n')
    count_sun = int(input("SUNDAY TOTAL CLASS: "))
    for i in range(0, count_sun):
        time = input("ENTER THE CLASS TIME IN INTERNATIONAL FORMAT : ")
        file.write(time + '\n')
        course_code = input("ENTER THE COURSE CODE : ")
        file.write(course_code + '\n')
        faculty = input("ENTER THE FACULTY SHORT FORM:  ")
        file.write(faculty + '\n')
        room_number = input("ENTER THE ROOM NUMBER : ")
        file.write(room_number + '\n')
        duration = input("ENTER THE CLASS DURATION: ")
        file.write(duration + '\n')

    #############MONDAY

    print('UPDATE YOUR INFORMATION FOR MONDAY : ')
    file.write('MON\n')
    count_mon = int(input("MONDAY TOTAL CLASS: "))
    for i in range(0, count_mon):
        time = input("ENTER THE CLASS TIME IN INTERNATIONAL FORMAT : ")
        file.write(time + '\n')
        course_code = input("ENTER THE COURSE CODE : ")
        file.write(course_code + '\n')
        faculty = input("ENTER THE FACULTY SHORT FORM:  ")
        file.write(faculty + '\n')
        room_number = input("ENTER THE ROOM NUMBER : ")
        file.write(room_number + '\n')
        duration = input("ENTER THE CLASS DURATION: ")
        file.write(duration + '\n')

    ##################### TUESDAY

    print('UPDATE YOUR INFORMATION FOR TUESDAY : ')
    file.write('TUE\n')
    count_tue = int(input("TUE TOTAL CLASS: "))
    for i in range(0, count_tue):
        time = input("ENTER THE CLASS TIME IN INTERNATIONAL FORMAT : ")
        file.write(time + '\n')
        course_code = input("ENTER THE COURSE CODE : ")
        file.write(course_code + '\n')
        faculty = input("ENTER THE FACULTY SHORT FORM:  ")
        file.write(faculty + '\n')
        room_number = input("ENTER THE ROOM NUMBER : ")
        file.write(room_number + '\n')
        duration = input("ENTER THE CLASS DURATION: ")
        file.write(duration + '\n')

    ################### WEDNESDAY

    print('UPDATE YOUR INFORMATION FOR WEDNESDAY : ')
    file.write('WED\n')
    count_wed = int(input("WEDNESDAY TOTAL CLASS: "))
    for i in range(0, count_wed):
        time = input("ENTER THE CLASS TIME IN INTERNATIONAL FORMAT : ")
        file.write(time + '\n')
        course_code = input("ENTER THE COURSE CODE : ")
        file.write(course_code + '\n')
        faculty = input("ENTER THE FACULTY SHORT FORM:  ")
        file.write(faculty + '\n')
        room_number = input("ENTER THE ROOM NUMBER : ")
        file.write(room_number + '\n')
        duration = input("ENTER THE CLASS DURATION: ")
        file.write(duration + '\n')

    ######################## THURSDAY :

    print('UPDATE YOUR INFORMATION FOR THURSDAY : ')
    file.write('THU\n')
    count_thu = int(input("THURSDAY TOTAL CLASS: "))
    for i in range(0, count_thu):
        time = input("ENTER THE CLASS TIME IN INTERNATIONAL FORMAT : ")
        file.write(time + '\n')
        course_code = input("ENTER THE COURSE CODE : ")
        file.write(course_code + '\n')
        faculty = input("ENTER THE FACULTY SHORT FORM:  ")
        file.write(faculty + '\n')
        room_number = input("ENTER THE ROOM NUMBER : ")
        file.write(room_number + '\n')
        duration = input("ENTER THE CLASS DURATION: ")
        file.write(duration + '\n')

    file.write('FRI\n')
    file.close()

    print('THANK YOU FOR UPDATING YOUR DATA ON OUR DATABASE')
